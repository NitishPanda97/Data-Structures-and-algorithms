# %%
import threading
import time

from collections import deque
class Queue:
    def __init__(self):
        self.buffer = deque()
        
    def enqueue(self,val):
        self.buffer.appendleft(val)
        
    def dequeue(self):
        if len(self.buffer)==0:
            print("Queue is empty!")
            return
        
        return self.buffer.pop()
    
    def is_empty(self):
        return len(self.buffer) == 0
    
    def size(self):
        return len(self.buffer)
    
food_order_queue = Queue()

def place_orders(orders):
    for order in orders:
        print('Placing order for: ',order)
        food_order_queue.enqueue(order)
        time.sleep(0.5)
        
def serve_orders():
    time.sleep(1)
    while True:
        order = food_order_queue.dequeue()
        print("Now serving order: ",order)
        time.sleep(2)

if __name__ == '__main__':
    orders = ['pizza','Berger','Samosa','Dosa','Idli']
    t1 = threading.Thread(target = place_orders , args = (orders,))
    t2 = threading.Thread(target = serve_orders)
    
    t1.start()
    t2.start()
# Out:
# Placing order for:  pizza
# Now serving:  pizza
# Placing order for:  Berger
# Placing order for:  Samosa
# Now serving order:  Berger
# Placing order for:  Dosa
# Placing order for:  Idli
# Now serving:  Samosa
# Now serving order:  Dosa
# Now serving:  Idli
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None
# Queue is empty!
# Now serving:  None
# Queue is empty!
# Now serving order:  None

# %%
# Out:
# Placing order for: pizza
# Placing order for: samosa
# Now serving:  pizza
# Placing order for: pasta
# Placing order for: biryani
# Placing order for: burger
# Now serving:  samosa
# Now serving:  pasta
# Now serving:  biryani
# Now serving:  burger
# Queue is empty
# Now serving:  None
# Queue is empty
# Now serving:  None
# Queue is empty
# Now serving:  None
# Queue is empty
# Now serving:  None
# Queue is empty
# Now serving:  None
