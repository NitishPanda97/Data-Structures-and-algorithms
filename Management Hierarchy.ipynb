# %%
class TreeNode:
    
    def __init__(self,name,designation):
        self.name = name
        self.designation = designation
        self.children = []
        self.parent = None
        
    def get_level(self):
        level = 0
        p = self.parent
        while p:
            level += 1
            p = p.parent
            
        return level
    
    def print_tree(self,property_name):
        if property_name == 'both':
            value = self.name + " (" + self.designation + ")"
        elif property_name == 'name':
            value = self.name
        else:
            value = self.designation
            
        spaces = ' ' * self.get_level() * 3
        prefix = spaces + "|__"if self.parent else ""
        print(prefix+value)
        if self.children:
            for child in self.children:
                child.print_tree(property_name)
        
    def add_child(self,child):
        child.parent = self
        self.children.append(child)
        
def build_management_tree():
    #CTO Hierarchy
    infra_head = TreeNode("Pritish","Infrastructure Head")
    infra_head.add_child(TreeNode("Satish","Cloud Manager"))
    infra_head.add_child(TreeNode("Udipta","App Manager"))
    
    cto = TreeNode("Akash","CTO")
    cto.add_child(infra_head)
    cto.add_child(TreeNode("Satyasai","Application Head"))
    
    #Hr hierarchy
    hr_head = TreeNode("Abinash","HR Head")
    
    hr_head.add_child(TreeNode("Debasish","Recruitment Manager"))
    hr_head.add_child(TreeNode("Sourav","Policy Manager"))
    
    ceo = TreeNode("Nitish","CEO")
    ceo.add_child(cto)
    ceo.add_child(hr_head)
    
    return ceo

if __name__ == '__main__':
    root_node = build_management_tree()
    root_node.print_tree("name")
    root_node.print_tree("designation")
    root_node.print_tree("both")
# Out:
# Nitish
#    |__Akash
#       |__Pritish
#          |__Satish
#          |__Udipta
#       |__Satyasai
#    |__Abinash
#       |__Debasish
#       |__Sourav
# CEO
#    |__CTO
#       |__Infrastructure Head
#          |__Cloud Manager
#          |__App Manager
#       |__Application Head
#    |__HR Head
#       |__Recruitment Manager
#       |__Policy Manager
# Nitish (CEO)
#    |__Akash (CTO)
#       |__Pritish (Infrastructure Head)
#          |__Satish (Cloud Manager)
#          |__Udipta (App Manager)
#       |__Satyasai (Application Head)
#    |__Abinash (HR Head)
#       |__Debasish (Recruitment Manager)
#       |__Sourav (Policy Manager)
